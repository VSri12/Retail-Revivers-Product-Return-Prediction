# %% [markdown]
# Importing required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Loading the Dataset

# %%
data = pd.read_csv("Dataset/order_dataset.csv")
data.head()
# Out:
#   Item Name   Category       Version                 Item Code     Item ID  \
# 0       QID  Product H   32 / B / 30  27-0CD-F44-7E1-0-2F608D7  46567054.0
# 1       OTH  Product P  32 / B / FtO  37-9D1-AC6-D48-E-F2D4507  16345004.0
# 2       WHX  Product P  32 / B / FtO  85-2EB-163-D62-5-FC50316  26246865.0
# 3       RJF  Product P  33 / B / FtO  3D-687-99C-14F-4-661E2E7  42015157.0
# 4       TSH  Product D  34 / B / FtO  F9-9FA-787-104-B-DCEE379  40522014.0
#
#     Buyer ID  Transaction ID        Date  Final Quantity  Total Revenue  \
# 0  3301861.0    5.363560e+13  14/04/2019               1          74.17
# 1  1205940.0    4.759180e+13  14/02/2019              -1           0.00
# 2  3342830.0    9.211720e+13  28/11/2018              -1           0.00
# 3  7251983.0    5.987730e+13    3/3/2019               1          79.17
# 4  9940388.0    3.658240e+13  26/11/2018               1          74.17
#
#    Price Reductions  Refunds  Final Revenue  Sales Tax  Overall Revenue  \
# ...

# %% [markdown]
# Checking Basic Info

# %%
# data.info()
data.describe()
# Out:
#             Item ID      Buyer ID  Transaction ID  Final Quantity  \
# count  7.005200e+04  7.005200e+04    7.005200e+04    70052.000000
# mean   2.442318e+11  6.013091e+11    5.506075e+13        0.701179
# std    4.255077e+12  6.223201e+12    2.587640e+13        0.739497
# min    1.001447e+07  1.000661e+06    1.000660e+13       -3.000000
# 25%    2.692223e+07  3.295695e+06    3.270320e+13        1.000000
# 50%    4.494514e+07  5.566107e+06    5.522210e+13        1.000000
# 75%    7.743106e+07  7.815352e+06    7.736880e+13        1.000000
# max    8.422210e+13  9.977410e+13    9.999550e+13        6.000000
#
#        Total Revenue  Price Reductions       Refunds  Final Revenue  \
# count   70052.000000      70052.000000  70052.000000   70052.000000
# mean       61.776302         -4.949904    -10.246051      46.580348
# std        31.800689          7.769972     25.154677      51.802690
# min         0.000000       -200.000000   -237.500000    -237.500000
# ...
